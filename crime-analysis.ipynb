# %% [markdown]
# # Crime Analysis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/crime-in-india/29_Period_of_trials_by_courts.csv
# /kaggle/input/crime-in-india/28_Trial_of_violent_crimes_by_courts.csv
# /kaggle/input/crime-in-india/20_Victims_of_rape.csv
# /kaggle/input/crime-in-india/35_Human_rights_violation_by_police.csv
# /kaggle/input/crime-in-india/40_04_Custodial_death_during_hospitalization_or_treatment.csv
# /kaggle/input/crime-in-india/39_Specific_purpose_of_kidnapping_and_abduction.csv
# /kaggle/input/crime-in-india/33_CH_not_murder_victim_age_sex.csv
# /kaggle/input/crime-in-india/36_Police_housing.csv
# /kaggle/input/crime-in-india/31_Serious_fraud.csv
# /kaggle/input/crime-in-india/43_Arrests_under_crime_against_women.csv
# /kaggle/input/crime-in-india/40_03_Custodial_death_during_production.csv
# /kaggle/input/crime-in-india/40_05_Custodial_death_others.csv
# /kaggle/input/crime-in-india/32_Murder_victim_age_sex.csv
# /kaggle/input/crime-in-india/30_Auto_theft.csv
# /kaggle/input/crime-in-india/40_01_Custodial_death_person_remanded.csv
# /kaggle/input/crime-in-india/40_02_Custodial_death_person_not_remanded.csv
# /kaggle/input/crime-in-india/42_Cases_under_crime_against_women.csv
# /kaggle/input/crime-in-india/10_Property_stolen_and_recovered.csv
# /kaggle/input/crime-in-india/25_Complaints_against_police.csv
# /kaggle/input/crime-in-india/crime/17_Case_reported_and_value_of_property_taken_away_by_place_of_occurrence_2013.csv
# /kaggle/input/crime-in-india/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2013.csv
# /kaggle/input/crime-in-india/crime/41_Escapes_from_police_custody.csv
# /kaggle/input/crime-in-india/crime/16_Casualties_under_police_firing_and_lathi_charge.csv
# /kaggle/input/crime-in-india/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2013.csv
# /kaggle/input/crime-in-india/crime/02_District_wise_crimes_committed_against_ST_2013.csv
# /kaggle/input/crime-in-india/crime/13_Police_killed_or_injured_on_duty.csv
# /kaggle/input/crime-in-india/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2014.csv
# /kaggle/input/crime-in-india/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2012.csv
# /kaggle/input/crime-in-india/crime/24_Anti_corruption_arrests.csv
# /kaggle/input/crime-in-india/crime/38_Unidentified_dead_bodies_recovered_and_inquest_conducted.csv
# /kaggle/input/crime-in-india/crime/17_Case_reported_and_value_of_property_taken_away_by_place_of_occurrence_2001_2012.csv
# /kaggle/input/crime-in-india/crime/42_District_wise_crimes_committed_against_women_2014.csv
# /kaggle/input/crime-in-india/crime/37_Home_guards_and_auxilliary_force.csv
# /kaggle/input/crime-in-india/crime/12_Police_strength_actual_and_sanctioned.csv
# /kaggle/input/crime-in-india/crime/27_Nature_of_complaints_received_by_police.csv
# /kaggle/input/crime-in-india/crime/08_02_Juvenile_apprehended_state_SLL.csv
# /kaggle/input/crime-in-india/crime/17_Crime_by_place_of_occurrence_2014.csv
# /kaggle/input/crime-in-india/crime/11_Property_stolen_and_recovered_nature_of_property.csv
# /kaggle/input/crime-in-india/crime/03_District_wise_crimes_committed_against_children_2001_2012.csv
# /kaggle/input/crime-in-india/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2013.csv
# /kaggle/input/crime-in-india/crime/42_District_wise_crimes_committed_against_women_2013.csv
# /kaggle/input/crime-in-india/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2014.csv
# /kaggle/input/crime-in-india/crime/18_04_Juveniles_arrested_Recidivism.csv
# /kaggle/input/crime-in-india/crime/15_Police_natural_death_and_suicide.csv
# /kaggle/input/crime-in-india/crime/02_District_wise_crimes_committed_against_ST_2014.csv
# /kaggle/input/crime-in-india/crime/09_Juveniles_arrested_and_their_disposal.csv
# /kaggle/input/crime-in-india/crime/02_01_District_wise_crimes_committed_against_SC_2001_2012.csv
# /kaggle/input/crime-in-india/crime/03_District_wise_crimes_committed_against_children_2013.csv
# /kaggle/input/crime-in-india/crime/02_District_wise_crimes_committed_against_ST_2001_2012.csv
# /kaggle/input/crime-in-india/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2014.csv
# /kaggle/input/crime-in-india/crime/02_01_District_wise_crimes_committed_against_SC_2013.csv
# /kaggle/input/crime-in-india/crime/02_01_District_wise_crimes_committed_against_SC_2014.csv
# /kaggle/input/crime-in-india/crime/18_01_Juveniles_arrested_Education.csv
# /kaggle/input/crime-in-india/crime/18_02_Juveniles_arrested_Economic_setup.csv
# /kaggle/input/crime-in-india/crime/22_Persons_arrested_under_recidivism.csv
# /kaggle/input/crime-in-india/crime/14_Age_profile_of_police_personnel_killed_on_duty.csv
# /kaggle/input/crime-in-india/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2012.csv
# /kaggle/input/crime-in-india/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2012.csv
# /kaggle/input/crime-in-india/crime/19_Motive_or_cause_of_murder_and_culpable_homicide_not_amounting_to_murder.csv
# /kaggle/input/crime-in-india/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2014.csv
# /kaggle/input/crime-in-india/crime/08_01_Juvenile_apprehended_state_IPC.csv
# /kaggle/input/crime-in-india/crime/18_03_Juveniles_arrested_Family_background.csv
# /kaggle/input/crime-in-india/crime/17_Crime_by_place_of_occurrence_2001_2012.csv
# /kaggle/input/crime-in-india/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2013.csv
# /kaggle/input/crime-in-india/crime/01_District_wise_crimes_committed_IPC_2013.csv
# /kaggle/input/crime-in-india/crime/21_Offenders_known_to_the_victim.csv
# /kaggle/input/crime-in-india/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2014.csv
# /kaggle/input/crime-in-india/crime/17_Crime_by_place_of_occurrence_2013.csv
# /kaggle/input/crime-in-india/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2012.csv
# /kaggle/input/crime-in-india/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2013.csv
# /kaggle/input/crime-in-india/crime/23_Anti_corruprion_cases.csv
# /kaggle/input/crime-in-india/crime/42_District_wise_crimes_committed_against_women_2001_2012.csv
# /kaggle/input/crime-in-india/crime/01_District_wise_crimes_committed_IPC_2001_2012.csv
# /kaggle/input/crime-in-india/crime/01_District_wise_crimes_committed_IPC_2014.csv
# /kaggle/input/crime-in-india/crime/34_Use_of_fire_arms_in_murder_cases.csv
# /kaggle/input/crime-in-india/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2012.csv
# /kaggle/input/crime-in-india/crime/crime/17_Case_reported_and_value_of_property_taken_away_by_place_of_occurrence_2013.csv
# /kaggle/input/crime-in-india/crime/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2013.csv
# /kaggle/input/crime-in-india/crime/crime/41_Escapes_from_police_custody.csv
# /kaggle/input/crime-in-india/crime/crime/16_Casualties_under_police_firing_and_lathi_charge.csv
# /kaggle/input/crime-in-india/crime/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2013.csv
# /kaggle/input/crime-in-india/crime/crime/02_District_wise_crimes_committed_against_ST_2013.csv
# /kaggle/input/crime-in-india/crime/crime/13_Police_killed_or_injured_on_duty.csv
# /kaggle/input/crime-in-india/crime/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2014.csv
# /kaggle/input/crime-in-india/crime/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2012.csv
# /kaggle/input/crime-in-india/crime/crime/24_Anti_corruption_arrests.csv
# /kaggle/input/crime-in-india/crime/crime/38_Unidentified_dead_bodies_recovered_and_inquest_conducted.csv
# /kaggle/input/crime-in-india/crime/crime/17_Case_reported_and_value_of_property_taken_away_by_place_of_occurrence_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/42_District_wise_crimes_committed_against_women_2014.csv
# /kaggle/input/crime-in-india/crime/crime/37_Home_guards_and_auxilliary_force.csv
# /kaggle/input/crime-in-india/crime/crime/12_Police_strength_actual_and_sanctioned.csv
# /kaggle/input/crime-in-india/crime/crime/27_Nature_of_complaints_received_by_police.csv
# /kaggle/input/crime-in-india/crime/crime/08_02_Juvenile_apprehended_state_SLL.csv
# /kaggle/input/crime-in-india/crime/crime/17_Crime_by_place_of_occurrence_2014.csv
# /kaggle/input/crime-in-india/crime/crime/11_Property_stolen_and_recovered_nature_of_property.csv
# /kaggle/input/crime-in-india/crime/crime/03_District_wise_crimes_committed_against_children_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2013.csv
# /kaggle/input/crime-in-india/crime/crime/42_District_wise_crimes_committed_against_women_2013.csv
# /kaggle/input/crime-in-india/crime/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2014.csv
# /kaggle/input/crime-in-india/crime/crime/18_04_Juveniles_arrested_Recidivism.csv
# /kaggle/input/crime-in-india/crime/crime/15_Police_natural_death_and_suicide.csv
# /kaggle/input/crime-in-india/crime/crime/02_District_wise_crimes_committed_against_ST_2014.csv
# /kaggle/input/crime-in-india/crime/crime/09_Juveniles_arrested_and_their_disposal.csv
# /kaggle/input/crime-in-india/crime/crime/02_01_District_wise_crimes_committed_against_SC_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/03_District_wise_crimes_committed_against_children_2013.csv
# /kaggle/input/crime-in-india/crime/crime/02_District_wise_crimes_committed_against_ST_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/07_01_Persons_arrested_by_sex_and_age_group_IPC_2014.csv
# /kaggle/input/crime-in-india/crime/crime/02_01_District_wise_crimes_committed_against_SC_2013.csv
# /kaggle/input/crime-in-india/crime/crime/02_01_District_wise_crimes_committed_against_SC_2014.csv
# /kaggle/input/crime-in-india/crime/crime/18_01_Juveniles_arrested_Education.csv
# /kaggle/input/crime-in-india/crime/crime/18_02_Juveniles_arrested_Economic_setup.csv
# /kaggle/input/crime-in-india/crime/crime/22_Persons_arrested_under_recidivism.csv
# /kaggle/input/crime-in-india/crime/crime/14_Age_profile_of_police_personnel_killed_on_duty.csv
# /kaggle/input/crime-in-india/crime/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2012.csv
# /kaggle/input/crime-in-india/crime/crime/07_02_Persons_arrested_by_sex_and_age_group_SLL_2012.csv
# /kaggle/input/crime-in-india/crime/crime/19_Motive_or_cause_of_murder_and_culpable_homicide_not_amounting_to_murder.csv
# /kaggle/input/crime-in-india/crime/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2014.csv
# /kaggle/input/crime-in-india/crime/crime/08_01_Juvenile_apprehended_state_IPC.csv
# /kaggle/input/crime-in-india/crime/crime/18_03_Juveniles_arrested_Family_background.csv
# /kaggle/input/crime-in-india/crime/crime/17_Crime_by_place_of_occurrence_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2013.csv
# /kaggle/input/crime-in-india/crime/crime/01_District_wise_crimes_committed_IPC_2013.csv
# /kaggle/input/crime-in-india/crime/crime/21_Offenders_known_to_the_victim.csv
# /kaggle/input/crime-in-india/crime/crime/04_02_Person_arrested_and_their_disposal_by_police_and_court_IPC_crime_2014.csv
# /kaggle/input/crime-in-india/crime/crime/17_Crime_by_place_of_occurrence_2013.csv
# /kaggle/input/crime-in-india/crime/crime/03_Persons_arrested_and_their_disposal_by_police_and_court_under_crime_against_children_2012.csv
# /kaggle/input/crime-in-india/crime/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2013.csv
# /kaggle/input/crime-in-india/crime/crime/23_Anti_corruprion_cases.csv
# /kaggle/input/crime-in-india/crime/crime/42_District_wise_crimes_committed_against_women_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/01_District_wise_crimes_committed_IPC_2001_2012.csv
# /kaggle/input/crime-in-india/crime/crime/01_District_wise_crimes_committed_IPC_2014.csv
# /kaggle/input/crime-in-india/crime/crime/34_Use_of_fire_arms_in_murder_cases.csv
# /kaggle/input/crime-in-india/crime/crime/04_01_Person_arrested_and_their_disposal_by_police_and_court_SLL_crime_2012.csv
# /kaggle/input/india-gis-data/India States/Indian_states.shp
# /kaggle/input/india-gis-data/India States/Indian_states.prj
# /kaggle/input/india-gis-data/India States/Indian_states.dbf
# /kaggle/input/india-gis-data/India States/Indian_states.shx
# /kaggle/input/india-gis-data/India Boundary/India_boundary.dbf
# /kaggle/input/india-gis-data/India Boundary/India_boundary.prj
# /kaggle/input/india-gis-data/India Boundary/India_boundary.shx
# /kaggle/input/india-gis-data/India Boundary/India_boundary.shp

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from plotly.offline import download_plotlyjs, init_notebook_mode , plot,iplot
import plotly.express as px
import plotly.graph_objects as go
from plotly.colors import n_colors
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
victims = pd.read_csv('../input/crime-in-india/20_Victims_of_rape.csv')
police_hr = pd.read_csv('../input/crime-in-india/35_Human_rights_violation_by_police.csv')
auto_theft = pd.read_csv('../input/crime-in-india/30_Auto_theft.csv')
prop_theft = pd.read_csv('../input/crime-in-india/10_Property_stolen_and_recovered.csv')
shp_gdf = gpd.read_file('../input/india-gis-data/India States/Indian_states.shp')

# %%
victims.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# 2                          2                          0
# 3                          1                          1
# 4                          0                          0
#
#    Victims_Between_30-50_Yrs  Victims_of_Rape_Total  Victims_Upto_10_Yrs
# 0                          0                      3                    0
# 1                          0                      1                    0
# 2                          0                      2                    0
# 3                          0                      2                    0
# 4                          0                      0                    0

# %%
rape_victims= victims[victims['Subgroup']=='Victims of Incest Rape']

# %%
rape_victims.head()
# Out:
#                     Area_Name  Year                Subgroup  \
# 1   Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 4   Andaman & Nicobar Islands  2002  Victims of Incest Rape
# 7   Andaman & Nicobar Islands  2003  Victims of Incest Rape
# 10  Andaman & Nicobar Islands  2004  Victims of Incest Rape
# 13  Andaman & Nicobar Islands  2005  Victims of Incest Rape
#
#     Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1                     1                     0                          0
# 4                     0                     0                          0
# 7                     0                     0                          0
# 10                    0                     0                          0
# 13                    0                     0                          0
#
#     Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1                           1                          0
# 4                           0                          0
# 7                           0                          0
# 10                          0                          0
# 13                          0                          0
#
#     Victims_Between_30-50_Yrs  Victims_of_Rape_Total  Victims_Upto_10_Yrs
# 1                           0                      1                    0
# 4                           0                      0                    0
# 7                           0                      0                    0
# 10                          0                      0                    0
# 13                          0                      0                    0

# %%
g= pd.DataFrame(rape_victims.groupby(['Year'])['Rape_Cases_Reported'].sum().reset_index())

# %%
g.head()
# Out:
#    Year  Rape_Cases_Reported
# 0  2001                  439
# 1  2002                  369
# 2  2003                  399
# 3  2004                  505
# 4  2005                  750

# %%
g.columns=['Year','Cases Reported']

# %%
g.columns
# Out:
# Index(['Year', 'Cases Reported'], dtype='object')

# %%
g
# Out:
#    Year  Cases Reported
# 0  2001             439
# 1  2002             369
# 2  2003             399
# 3  2004             505
# 4  2005             750
# 5  2006             431
# 6  2007             405
# 7  2008             309
# 8  2009             321
# 9  2010             288

# %%
fig= px.bar(g,x='Year',y='Cases Reported',color_discrete_sequence=['blue'])
fig.show()

# %%
g1= pd.DataFrame(rape_victims.groupby(['Area_Name'])['Rape_Cases_Reported'].sum().reset_index())

# %%
g1.head()
# Out:
#                     State/UT  Cases Reported
# 0  Andaman & Nicobar Islands               1
# 1             Andhra Pradesh              70
# 2         Arunanchal Pradesh               0
# 3                      Assam             101
# 4                      Bihar              43

# %%
g1.columns=['State/UT','Cases Reported']

# %%
g1.columns
# Out:
# Index(['State/UT', 'Cases Reported'], dtype='object')

# %%
g1.replace(to_replace='Arunachal Pradesh',value='Arunanchal Pradesh',inplace=True)

# %%
g1
# Out:
#                      State/UT  Cases Reported
# 0   Andaman & Nicobar Islands               1
# 1              Andhra Pradesh              70
# 2          Arunanchal Pradesh               0
# 3                       Assam             101
# 4                       Bihar              43
# 5                  Chandigarh              17
# 6                Chhattisgarh             532
# 7        Dadra & Nagar Haveli               0
# 8                 Daman & Diu               0
# 9                       Delhi             231
# 10                        Goa               7
# 11                    Gujarat              97
# 12                    Haryana             149
# 13           Himachal Pradesh              43
# 14            Jammu & Kashmir              12
# 15                  Jharkhand             321
# 16                  Karnataka              46
# 17                     Kerala             128
# 18                Lakshadweep               0
# 19             Madhya Pradesh             865
# 20                Maharashtra             359
# 21                    Manipur               7
# 22                  Meghalaya              46
# 23                    Mizoram              13
# 24                   Nagaland               4
# 25                     Odisha              73
# 26                 Puducherry               0
# 27                     Punjab             163
# 28                  Rajasthan             337
# 29                     Sikkim              10
# 30                 Tamil Nadu             116
# 31                    Tripura               5
# 32              Uttar Pradesh             138
# 33                Uttarakhand              71
# 34                West Bengal             211

# %%
shp_gdf
# Out:
#                        st_nm  \
# 0   Andaman & Nicobar Island
# 1         Arunanchal Pradesh
# 2                      Assam
# 3                      Bihar
# 4                 Chandigarh
# 5               Chhattisgarh
# 6     Dadara & Nagar Havelli
# 7                Daman & Diu
# 8                        Goa
# 9                    Gujarat
# 10                   Haryana
# 11          Himachal Pradesh
# 12           Jammu & Kashmir
# 13                 Jharkhand
# 14                 Karnataka
# 15                    Kerala
# 16               Lakshadweep
# 17            Madhya Pradesh
# 18               Maharashtra
# 19                   Manipur
# 20                 Meghalaya
# 21                   Mizoram
# 22                  Nagaland
# 23              NCT of Delhi
# 24                Puducherry
# 25                    Punjab
# 26                 Rajasthan
# 27                    Sikkim
# 28                Tamil Nadu
# 29                 Telangana
# 30                   Tripura
# 31             Uttar Pradesh
# 32               Uttarakhand
# 33               West Bengal
# 34                    Odisha
# 35            Andhra Pradesh
#
#                                              geometry
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# 6   POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# 7   MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# 10  POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# 11  POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# 12  POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# 13  POLYGON ((87.60582 25.31512, 87.61279 25.31184...
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# 15  POLYGON ((74.99575 12.79227, 75.00006 12.78777...
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# 19  POLYGON ((94.57602 25.64221, 94.57487 25.63858...
# 20  POLYGON ((91.85632 26.10353, 91.86717 26.09906...
# 21  POLYGON ((92.80022 24.41630, 92.80310 24.41603...
# 22  POLYGON ((95.21458 26.93095, 95.21719 26.92818...
# 23  POLYGON ((77.09361 28.86940, 77.10973 28.86722...
# 24  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# 25  POLYGON ((75.88469 32.48841, 75.90303 32.47169...
# 26  POLYGON ((73.89849 29.97896, 73.90021 29.97140...
# 27  POLYGON ((88.65381 28.09883, 88.66265 28.08956...
# 28  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...
# 29  POLYGON ((81.05614 17.79097, 81.05834 17.75464...
# 30  POLYGON ((92.22108 24.50131, 92.22771 24.49862...
# 31  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# 32  POLYGON ((79.21047 31.34846, 79.21386 31.34680...
# 33  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 34  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# 35  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...

# %%
merge =shp_gdf.set_index('st_nm').join(g1.set_index('State/UT'))

# %%
merge
# Out:
#                                                                    geometry  \
# st_nm
# Andaman & Nicobar Island  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Arunanchal Pradesh        POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# Assam                     MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# Bihar                     MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# Chandigarh                POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# Chhattisgarh              POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# Dadara & Nagar Havelli    POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# Daman & Diu               MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# Goa                       MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# Gujarat                   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# Haryana                   POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# Himachal Pradesh          POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# Jammu & Kashmir           POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# Jharkhand                 POLYGON ((87.60582 25.31512, 87.61279 25.31184...
# Karnataka                 MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# Kerala                    POLYGON ((74.99575 12.79227, 75.00006 12.78777...
# Lakshadweep               MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...
# Madhya Pradesh            MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# Maharashtra               MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# Manipur                   POLYGON ((94.57602 25.64221, 94.57487 25.63858...
# Meghalaya                 POLYGON ((91.85632 26.10353, 91.86717 26.09906...
# Mizoram                   POLYGON ((92.80022 24.41630, 92.80310 24.41603...
# Nagaland                  POLYGON ((95.21458 26.93095, 95.21719 26.92818...
# NCT of Delhi              POLYGON ((77.09361 28.86940, 77.10973 28.86722...
# Puducherry                MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# Punjab                    POLYGON ((75.88469 32.48841, 75.90303 32.47169...
# Rajasthan                 POLYGON ((73.89849 29.97896, 73.90021 29.97140...
# Sikkim                    POLYGON ((88.65381 28.09883, 88.66265 28.08956...
# Tamil Nadu                MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...
# Telangana                 POLYGON ((81.05614 17.79097, 81.05834 17.75464...
# Tripura                   POLYGON ((92.22108 24.50131, 92.22771 24.49862...
# Uttar Pradesh             MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# Uttarakhand               POLYGON ((79.21047 31.34846, 79.21386 31.34680...
# West Bengal               MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# Odisha                    MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# Andhra Pradesh            MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
#
#                           Cases Reported
# st_nm
# Andaman & Nicobar Island             NaN
# Arunanchal Pradesh                   0.0
# Assam                              101.0
# Bihar                               43.0
# Chandigarh                          17.0
# Chhattisgarh                       532.0
# Dadara & Nagar Havelli               NaN
# Daman & Diu                          0.0
# Goa                                  7.0
# Gujarat                             97.0
# Haryana                            149.0
# Himachal Pradesh                    43.0
# Jammu & Kashmir                     12.0
# Jharkhand                          321.0
# Karnataka                           46.0
# Kerala                             128.0
# Lakshadweep                          0.0
# Madhya Pradesh                     865.0
# Maharashtra                        359.0
# Manipur                              7.0
# Meghalaya                           46.0
# Mizoram                             13.0
# Nagaland                             4.0
# NCT of Delhi                         NaN
# Puducherry                           0.0
# Punjab                             163.0
# Rajasthan                          337.0
# Sikkim                              10.0
# Tamil Nadu                         116.0
# Telangana                            NaN
# Tripura                              5.0
# Uttar Pradesh                      138.0
# Uttarakhand                         71.0
# West Bengal                        211.0
# Odisha                              73.0
# Andhra Pradesh                      70.0

# %%
fig,ax=plt.subplots(1, figsize=(10,10))

ax.set_title('State-wise Rape-Cases Reported (2001-2010)',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merge.plot(column='Cases Reported', cmap='Reds', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
above_50 = rape_victims['Victims_Above_50_Yrs'].sum()
ten_to_14 = rape_victims['Victims_Between_10-14_Yrs'].sum()
fourteen_to_18 = rape_victims['Victims_Between_14-18_Yrs'].sum()
eighteen_to_30 = rape_victims['Victims_Between_18-30_Yrs'].sum()
thirty_to_50 = rape_victims['Victims_Between_30-50_Yrs'].sum()
upto_10 = rape_victims['Victims_Upto_10_Yrs'].sum()

# %%
age_grp = ['Upto 10','10 to 14','14 to 18','18 to 30','30 to 50','Above 50']
age_group_vals = [upto_10,ten_to_14,fourteen_to_18,eighteen_to_30,thirty_to_50,above_50]

fig = go.Figure(data=[go.Pie(labels=age_grp, values=age_group_vals,sort=True,
                            marker=dict(colors=px.colors.qualitative.G10),textfont_size=12)])

fig.show()

# %%
g2= pd.DataFrame(police_hr.groupby(['Area_Name'])['Cases_Registered_under_Human_Rights_Violations'].sum().reset_index())

# %%
g2.columns= ['State/UT','Cases Reported']

# %%
g2.head()
# Out:
#              State/UT  Cases Reported
# 0      Andhra Pradesh           226.0
# 1  Arunanchal Pradesh            40.0
# 2               Assam           302.0
# 3               Bihar            52.0
# 4          Chandigarh             2.0

# %%
g2.replace(to_replace='Arunachal Pradesh',value='Arunanchal Pradesh',inplace=True)

shp_gdf = gpd.read_file('../input/india-gis-data/India States/Indian_states.shp')
merged = shp_gdf.set_index('st_nm').join(g2.set_index('State/UT'))

# %%
shp_gdf
# Out:
#                        st_nm  \
# 0   Andaman & Nicobar Island
# 1         Arunanchal Pradesh
# 2                      Assam
# 3                      Bihar
# 4                 Chandigarh
# 5               Chhattisgarh
# 6     Dadara & Nagar Havelli
# 7                Daman & Diu
# 8                        Goa
# 9                    Gujarat
# 10                   Haryana
# 11          Himachal Pradesh
# 12           Jammu & Kashmir
# 13                 Jharkhand
# 14                 Karnataka
# 15                    Kerala
# 16               Lakshadweep
# 17            Madhya Pradesh
# 18               Maharashtra
# 19                   Manipur
# 20                 Meghalaya
# 21                   Mizoram
# 22                  Nagaland
# 23              NCT of Delhi
# 24                Puducherry
# 25                    Punjab
# 26                 Rajasthan
# 27                    Sikkim
# 28                Tamil Nadu
# 29                 Telangana
# 30                   Tripura
# 31             Uttar Pradesh
# 32               Uttarakhand
# 33               West Bengal
# 34                    Odisha
# 35            Andhra Pradesh
#
#                                              geometry
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# 6   POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# 7   MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# 10  POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# 11  POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# 12  POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# 13  POLYGON ((87.60582 25.31512, 87.61279 25.31184...
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# 15  POLYGON ((74.99575 12.79227, 75.00006 12.78777...
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# 19  POLYGON ((94.57602 25.64221, 94.57487 25.63858...
# 20  POLYGON ((91.85632 26.10353, 91.86717 26.09906...
# 21  POLYGON ((92.80022 24.41630, 92.80310 24.41603...
# 22  POLYGON ((95.21458 26.93095, 95.21719 26.92818...
# 23  POLYGON ((77.09361 28.86940, 77.10973 28.86722...
# 24  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# 25  POLYGON ((75.88469 32.48841, 75.90303 32.47169...
# 26  POLYGON ((73.89849 29.97896, 73.90021 29.97140...
# 27  POLYGON ((88.65381 28.09883, 88.66265 28.08956...
# 28  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...
# 29  POLYGON ((81.05614 17.79097, 81.05834 17.75464...
# 30  POLYGON ((92.22108 24.50131, 92.22771 24.49862...
# 31  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# 32  POLYGON ((79.21047 31.34846, 79.21386 31.34680...
# 33  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 34  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# 35  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Property Stolen-Cases Reported',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='Cases Reported', cmap='RdPu', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
g3 = pd.DataFrame(police_hr.groupby(['Year'])['Cases_Registered_under_Human_Rights_Violations'].sum().reset_index())
g3.columns = ['Year','Cases Registered']

fig = px.bar(g3,x='Year',y='Cases Registered',color_discrete_sequence=['black'])
fig.show()

# %%
police_hr.Group_Name.value_counts()
# Out:
# HR_Total Violations by Police                 214
# HR_Others Violations by Police                194
# HR_Disappearance of Persons                   190
# HR_Extortion                                  190
# HR_Torture                                    190
# HR_Atrocities on SC/ST                        188
# HR_Illegal detention/arrests                  186
# HR_Fake encounter killings                    185
# HR_Indignity to Women                         185
# HR_Violation against Terrorists/Extremists    182
# HR_False implication                          182
# HR_Failure in taking action                   181
# Name: Group_Name, dtype: int64

# %%
fake_enc_df = police_hr[police_hr['Group_Name']=='HR_Fake encounter killings'] 
fake_enc_df.Cases_Registered_under_Human_Rights_Violations.sum()
# Out:
# 16.0

# %%
false_imp_df = police_hr[police_hr['Group_Name']=='HR_False implication'] 
false_imp_df.Cases_Registered_under_Human_Rights_Violations.sum()
# Out:
# 29.0

# %%
g4 = pd.DataFrame(police_hr.groupby(['Year'])['Policemen_Chargesheeted','Policemen_Convicted'].sum().reset_index())

# %%
g4
# Out:
#    Year  Policemen_Chargesheeted  Policemen_Convicted
# 0  2001                    270.0                  4.0
# 1  2002                    118.0                  0.0
# 2  2003                     46.0                 20.0
# 3  2004                     44.0                  0.0
# 4  2005                     42.0                  0.0
# 5  2006                     56.0                  0.0
# 6  2007                     74.0                  0.0
# 7  2008                     28.0                 16.0
# 8  2009                    166.0                116.0
# 9  2010                     28.0                  8.0

# %%
year=['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010']

fig = go.Figure(data=[
    go.Bar(name='Policemen Chargesheeted', x=year, y=g4['Policemen_Chargesheeted'],
           marker_color='purple'),
    go.Bar(name='Policemen Convicted', x=year, y=g4['Policemen_Convicted'],
          marker_color='red')
])

fig.update_layout(barmode='group',xaxis_title='Year',yaxis_title='Number of policemen')
fig.show()

# %%
g5 = pd.DataFrame(auto_theft.groupby(['Area_Name'])['Auto_Theft_Stolen'].sum().reset_index())
g5.columns = ['State/UT','Vehicle_Stolen']
g5.replace(to_replace='Arunachal Pradesh',value='Arunanchal Pradesh',inplace=True)

shp_gdf = gpd.read_file('../input/india-gis-data/India States/Indian_states.shp')
merged = shp_gdf.set_index('st_nm').join(g5.set_index('State/UT'))

fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Auto Theft Cases Reported(2001-2010)',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='Vehicle_Stolen', cmap='YlOrBr', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)

# %%
auto_theft_traced = auto_theft['Auto_Theft_Coordinated/Traced'].sum()
auto_theft_recovered = auto_theft['Auto_Theft_Recovered'].sum()
auto_theft_stolen = auto_theft['Auto_Theft_Stolen'].sum()

vehicle_group = ['Vehicles Stolen','Vehicles Traced','Vehicles Recovered']
vehicle_vals = [auto_theft_stolen,auto_theft_traced,auto_theft_recovered]

colors = ['hotpink','purple','red']

fig = go.Figure(data=[go.Pie(labels=vehicle_group, values=vehicle_vals,sort=False,
                            marker=dict(colors=colors),textfont_size=12)])

fig.show()

# %%
g5 = pd.DataFrame(auto_theft.groupby(['Year'])['Auto_Theft_Stolen'].sum().reset_index())

g5.columns = ['Year','Vehicles Stolen']

fig = px.bar(g5,x='Year',y='Vehicles Stolen',color_discrete_sequence=['#00CC96'])
fig.show()

# %%
vehicle_list = ['Motor Cycles/ Scooters','Motor Car/Taxi/Jeep','Buses',
               'Goods carrying vehicles (Trucks/Tempo etc)','Other Motor vehicles']

sr_no = [1,2,3,4,5]

fig = go.Figure(data=[go.Table(header=dict(values=['Sr No','Vehicle type'],
                                          fill_color='turquoise',
                                           height=30),
                 cells=dict(values=[sr_no,vehicle_list],
                            height=30))
                     ])
fig.show()

# %%
motor_c = auto_theft[auto_theft['Sub_Group_Name']=='1. Motor Cycles/ Scooters']

g8 = pd.DataFrame(motor_c.groupby(['Area_Name'])['Auto_Theft_Stolen'].sum().reset_index())
g8_sorted = g8.sort_values(['Auto_Theft_Stolen'],ascending=True)
fig = px.scatter(g8_sorted.iloc[-10:,:], y='Area_Name', x='Auto_Theft_Stolen',
             orientation='h',color_discrete_sequence=["red"])
fig.show()

# %%
g7 = pd.DataFrame(prop_theft.groupby(['Area_Name'])['Cases_Property_Stolen'].sum().reset_index())
g7.columns = ['State/UT','Cases Reported']
g7.replace(to_replace='Arunachal Pradesh',value='Arunanchal Pradesh',inplace=True)

shp_gdf = gpd.read_file('../input/india-gis-data/India States/Indian_states.shp')
merged = shp_gdf.set_index('st_nm').join(g7.set_index('State/UT'))

fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')
ax.set_title('State-wise Property Stolen-Cases Reported',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = merged.plot(column='Cases Reported', cmap='spring', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)
